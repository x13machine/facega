# %%
import sys
print(sys.executable)
# Out:
# /home/brandan/.local/share/virtualenvs/facega-KSwrb5u3/bin/python3.6m

# %%
import os
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"   # see issue #152
os.environ["CUDA_VISIBLE_DEVICES"] = ""
from keras.models import load_model
import numpy as np
from scipy.stats import norm
import random
import matplotlib.pyplot as plt
from tqdm import tqdm_notebook
# Out:
# Using TensorFlow backend.

# %%
# !ls
# Out:
# autoencoders/0.0.1/decoder-f64.h5

# %%
decoder = load_model('autoencoders/0.0.1/decoder-f64.h5')
# Out:
# /home/brandan/.local/share/virtualenvs/facega-KSwrb5u3/lib/python3.6/site-packages/keras/engine/saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '

# %%
for _ in range(5):
    li = []
    for _ in range(300):
        li.append(norm.ppf(random.random()))
    img = decoder.predict(np.array([li]))
    img = img.reshape((64,64,3))

    plt.imshow(img)
    plt.show()
